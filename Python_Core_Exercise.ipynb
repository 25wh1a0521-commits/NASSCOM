# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0521-commits/NASSCOM/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):
    # Timestamp in the format YYYY-MM-DD HH:MM:SS
    timestamp_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Unique device ID
    device_id = f"DEV{i:03d}"

    # Randomly choose device type
    device_type = random.choice(DEVICE_TYPES)

    # Randomly choose location
    location = random.choice(LOCATIONS)

    # Generate random value based on device type
    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    # Create a tuple
    reading = (timestamp_str, device_id, device_type, location, value)

    # Add tuple to the list
    raw_sensor_data.append(reading)

# Print all sensor readings
print("\nGenerated Sensor Readings:")
for reading in raw_sensor_data:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# Generated Sensor Readings:
# ('2026-07-19 15:01:37', 'DEV001', 'Light_Sensor', 'Lab2', 998.0)
# ('2026-07-19 15:01:37', 'DEV002', 'Temperature_Sensor', 'OfficeA', 27.65)
# ('2026-07-19 15:01:37', 'DEV003', 'Humidity_Sensor', 'Lab2', 67.63)
# ('2026-07-19 15:01:37', 'DEV004', 'Temperature_Sensor', 'Lab1', 29.82)
# ('2026-07-19 15:01:37', 'DEV005', 'Light_Sensor', 'OfficeA', 290.2)
# ('2026-07-19 15:01:37', 'DEV006', 'Temperature_Sensor', 'Lab1', 22.97)
# ('2026-07-19 15:01:37', 'DEV007', 'Pressure_Sensor', 'Lab2', 983.1)
# ('2026-07-19 15:01:37', 'DEV008', 'Pressure_Sensor', 'OfficeB', 1016.77)
# ('2026-07-19 15:01:37', 'DEV009', 'Light_Sensor', 'OfficeA', 411.94)
# ('2026-07-19 15:01:37', 'DEV010', 'Humidity_Sensor', 'Lab2', 44.9)
# ('2026-07-19 15:01:37', 'DEV011', 'Light_Sensor', 'Lab1', 279.14)
# ('2026-07-19 15:01:37', 'DEV012', 'Temperature_Sensor', 'Lab2', 19.93)
# ('2026-07-19 15:01:37', 'DEV013', 'Light_Sensor', 'Lab2', 285.04)
# ('2026-07-19 15:01:37', 'DEV014', 'Light_Sensor', 'Warehouse', 694.46)
# ('2026-07-19 15:01:37', 'DEV015', 'Pressure_Sensor', 'OfficeB', 1022.87)
# ('2026-07-19 15:01:37', 'DEV016', 'Light_Sensor', 'Lab2', 864.94)
# ('2026-07-19 15:01:37', 'DEV017', 'Humidity_Sensor', 'OfficeB', 33.55)
# ('2026-07-19 15:01:37', 'DEV018', 'Pressure_Sensor', 'OfficeB', 1005.07)
# ('2026-07-19 15:01:37', 'DEV019', 'Light_Sensor', 'OfficeA', 289.42)
# ('2026-07-19 15:01:37', 'DEV020', 'Humidity_Sensor', 'Lab2', 67.15)
# ('2026-07-19 15:01:37', 'DEV021', 'Light_Sensor', 'Lab1', 880.17)
# ('2026-07-19 15:01:37', 'DEV022', 'Humidity_Sensor', 'Lab1', 51.22)
# ('2026-07-19 15:01:37', 'DEV023', 'Pressure_Sensor', 'Lab2', 1002.06)
# ('2026-07-19 15:01:37', 'DEV024', 'Light_Sensor', 'OfficeB', 560.67)
# ('2026-07-19 15:01:37', 'DEV025', 'Light_Sensor', 'OfficeA', 734.54)
# ('2026-07-19 15:01:37', 'DEV026', 'Pressure_Sensor', 'Warehouse', 1018.84)
# ('2026-07-19 15:01:37', 'DEV027', 'Light_Sensor', 'Lab2', 397.82)
# ('2026-07-19 15:01:37', 'DEV028', 'Temperature_Sensor', 'OfficeA', 21.95)
# ('2026-07-19 15:01:37', 'DEV029', 'Pressure_Sensor', 'Lab2', 1016.36)
# ('2026-07-19 15:01:37', 'DEV030', 'Pressure_Sensor', 'Lab1', 988.79)
# ('2026-07-19 15:01:37', 'DEV031', 'Humidity_Sensor', 'Lab2', 46.22)
# ('2026-07-19 15:01:37', 'DEV032', 'Humidity_Sensor', 'OfficeB', 41.99)
# ('2026-07-19 15:01:37', 'DEV033', 'Light_Sensor', 'OfficeA', 823.84)
# ('2026-07-19 15:01:37', 'DEV034', 'Pressure_Sensor', 'OfficeA', 1005.59)
# ('2026-07-19 15:01:37', 'DEV035', 'Temperature_Sensor', 'OfficeB', 26.78)
# ('2026-07-19 15:01:37', 'DEV036', 'Temperature_Sensor', 'Lab1', 25.56)
# ('2026-07-19 15:01:37', 'DEV037', 'Pressure_Sensor', 'Warehouse', 1028.75)
# ('2026-07-19 15:01:37', 'DEV038', 'Temperature_Sensor', 'Lab2', 19.23)
# ('2026-07-19 15:01:37', 'DEV039', 'Humidity_Sensor', 'OfficeB', 52.82)
# ('2026-07-19 15:01:37', 'DEV040', 'Pressure_Sensor', 'OfficeB', 980.31)
# ('2026-07-19 15:01:37', 'DEV041', 'Temperature_Sensor', 'OfficeB', 22.12)
# ('2026-07-19 15:01:37', 'DEV042', 'Temperature_Sensor', 'OfficeA', 26.26)
# ('2026-07-19 15:01:37', 'DEV043', 'Humidity_Sensor', 'Warehouse', 56.05)
# ('2026-07-19 15:01:37', 'DEV044', 'Light_Sensor', 'OfficeB', 922.35)
# ('2026-07-19 15:01:37', 'DEV045', 'Pressure_Sensor', 'Lab1', 996.64)
# ('2026-07-19 15:01:37', 'DEV046', 'Humidity_Sensor', 'OfficeA', 77.13)
# ('2026-07-19 15:01:37', 'DEV047', 'Pressure_Sensor', 'OfficeB', 1029.92)
# ('2026-07-19 15:01:37', 'DEV048', 'Temperature_Sensor', 'Lab1', 18.38)
# ('2026-07-19 15:01:37', 'DEV049', 'Humidity_Sensor', 'Lab1', 48.08)
# ('2026-07-19 15:01:37', 'DEV050', 'Pressure_Sensor', 'OfficeA', 992.06)
# ('2026-07-19 15:01:37', 'DEV051', 'Pressure_Sensor', 'OfficeA', 981.15)
# ('2026-07-19 15:01:37', 'DEV052', 'Humidity_Sensor', 'OfficeB', 70.6)
# ('2026-07-19 15:01:37', 'DEV053', 'Humidity_Sensor', 'Lab2', 66.15)
# ('2026-07-19 15:01:37', 'DEV054', 'Temperature_Sensor', 'Lab1', 28.87)
# ('2026-07-19 15:01:37', 'DEV055', 'Temperature_Sensor', 'OfficeA', 19.01)
# ('2026-07-19 15:01:37', 'DEV056', 'Humidity_Sensor', 'Warehouse', 61.68)
# ('2026-07-19 15:01:37', 'DEV057', 'Light_Sensor', 'Lab2', 501.23)
# ('2026-07-19 15:01:37', 'DEV058', 'Pressure_Sensor', 'OfficeA', 1015.03)
# ('2026-07-19 15:01:37', 'DEV059', 'Humidity_Sensor', 'OfficeB', 68.86)
# ('2026-07-19 15:01:37', 'DEV060', 'Pressure_Sensor', 'Lab2', 1002.04)
# ('2026-07-19 15:01:37', 'DEV061', 'Humidity_Sensor', 'OfficeB', 58.64)
# ('2026-07-19 15:01:37', 'DEV062', 'Light_Sensor', 'Lab1', 808.97)
# ('2026-07-19 15:01:37', 'DEV063', 'Humidity_Sensor', 'OfficeA', 65.11)
# ('2026-07-19 15:01:37', 'DEV064', 'Light_Sensor', 'Warehouse', 269.68)
# ('2026-07-19 15:01:37', 'DEV065', 'Pressure_Sensor', 'Lab1', 989.63)
# ('2026-07-19 15:01:37', 'DEV066', 'Light_Sensor', 'OfficeA', 669.51)
# ('2026-07-19 15:01:37', 'DEV067', 'Pressure_Sensor', 'OfficeA', 1012.47)
# ('2026-07-19 15:01:37', 'DEV068', 'Humidity_Sensor', 'OfficeA', 53.88)
# ('2026-07-19 15:01:37', 'DEV069', 'Pressure_Sensor', 'OfficeA', 1013.85)
# ('2026-07-19 15:01:37', 'DEV070', 'Pressure_Sensor', 'OfficeA', 995.71)
# ('2026-07-19 15:01:37', 'DEV071', 'Humidity_Sensor', 'OfficeB', 43.65)
# ('2026-07-19 15:01:37', 'DEV072', 'Temperature_Sensor', 'OfficeA', 26.36)
# ('2026-07-19 15:01:37', 'DEV073', 'Pressure_Sensor', 'Warehouse', 984.86)
# ('2026-07-19 15:01:37', 'DEV074', 'Temperature_Sensor', 'Lab2', 18.71)
# ('2026-07-19 15:01:37', 'DEV075', 'Humidity_Sensor', 'Warehouse', 43.65)
# ('2026-07-19 15:01:37', 'DEV076', 'Humidity_Sensor', 'OfficeB', 75.79)
# ('2026-07-19 15:01:37', 'DEV077', 'Light_Sensor', 'Lab1', 895.32)
# ('2026-07-19 15:01:37', 'DEV078', 'Humidity_Sensor', 'Lab1', 77.12)
# ('2026-07-19 15:01:37', 'DEV079', 'Temperature_Sensor', 'Warehouse', 22.3)
# ('2026-07-19 15:01:37', 'DEV080', 'Light_Sensor', 'OfficeA', 967.69)
# ('2026-07-19 15:01:37', 'DEV081', 'Temperature_Sensor', 'Warehouse', 28.92)
# ('2026-07-19 15:01:37', 'DEV082', 'Humidity_Sensor', 'Warehouse', 48.79)
# ('2026-07-19 15:01:37', 'DEV083', 'Light_Sensor', 'Warehouse', 528.23)
# ('2026-07-19 15:01:37', 'DEV084', 'Humidity_Sensor', 'Lab2', 71.9)
# ('2026-07-19 15:01:37', 'DEV085', 'Temperature_Sensor', 'Lab1', 28.48)
# ('2026-07-19 15:01:37', 'DEV086', 'Light_Sensor', 'OfficeB', 182.4)
# ('2026-07-19 15:01:37', 'DEV087', 'Light_Sensor', 'OfficeA', 771.26)
# ('2026-07-19 15:01:37', 'DEV088', 'Light_Sensor', 'OfficeA', 679.98)
# ('2026-07-19 15:01:37', 'DEV089', 'Pressure_Sensor', 'Warehouse', 1006.43)
# ('2026-07-19 15:01:37', 'DEV090', 'Light_Sensor', 'Warehouse', 764.68)
# ('2026-07-19 15:01:37', 'DEV091', 'Humidity_Sensor', 'Lab1', 55.2)
# ('2026-07-19 15:01:37', 'DEV092', 'Temperature_Sensor', 'Lab2', 26.35)
# ('2026-07-19 15:01:37', 'DEV093', 'Humidity_Sensor', 'OfficeB', 52.66)
# ('2026-07-19 15:01:37', 'DEV094', 'Humidity_Sensor', 'OfficeA', 42.12)
# ('2026-07-19 15:01:37', 'DEV095', 'Light_Sensor', 'Warehouse', 727.54)
# ('2026-07-19 15:01:37', 'DEV096', 'Pressure_Sensor', 'Warehouse', 984.49)
# ('2026-07-19 15:01:37', 'DEV097', 'Humidity_Sensor', 'OfficeA', 46.33)
# ('2026-07-19 15:01:37', 'DEV098', 'Temperature_Sensor', 'Warehouse', 29.35)
# ('2026-07-19 15:01:37', 'DEV099', 'Temperature_Sensor', 'Lab2', 18.4)
# ('2026-07-19 15:01:37', 'DEV100', 'Temperature_Sensor', 'Lab2', 21.43)

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temp_dict = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp_dict)

# Print the temperature readings
print("\nTemperature Readings:")
for temp in temperature_readings:
    print(temp)
# Out:
# Temperature Readings:
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV002', 'location': 'OfficeA', 'temperature_celsius': 27.65}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV004', 'location': 'Lab1', 'temperature_celsius': 29.82}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV006', 'location': 'Lab1', 'temperature_celsius': 22.97}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV012', 'location': 'Lab2', 'temperature_celsius': 19.93}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV028', 'location': 'OfficeA', 'temperature_celsius': 21.95}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV035', 'location': 'OfficeB', 'temperature_celsius': 26.78}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV036', 'location': 'Lab1', 'temperature_celsius': 25.56}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV038', 'location': 'Lab2', 'temperature_celsius': 19.23}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV041', 'location': 'OfficeB', 'temperature_celsius': 22.12}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV042', 'location': 'OfficeA', 'temperature_celsius': 26.26}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV048', 'location': 'Lab1', 'temperature_celsius': 18.38}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV054', 'location': 'Lab1', 'temperature_celsius': 28.87}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV055', 'location': 'OfficeA', 'temperature_celsius': 19.01}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV072', 'location': 'OfficeA', 'temperature_celsius': 26.36}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV074', 'location': 'Lab2', 'temperature_celsius': 18.71}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV079', 'location': 'Warehouse', 'temperature_celsius': 22.3}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV081', 'location': 'Warehouse', 'temperature_celsius': 28.92}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV085', 'location': 'Lab1', 'temperature_celsius': 28.48}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV092', 'location': 'Lab2', 'temperature_celsius': 26.35}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV098', 'location': 'Warehouse', 'temperature_celsius': 29.35}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV099', 'location': 'Lab2', 'temperature_celsius': 18.4}
# {'timestamp': '2026-07-19 15:01:37', 'device_id': 'DEV100', 'location': 'Lab2', 'temperature_celsius': 21.43}

# %%
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])   # Index 3 is the location

# Print the unique locations
print("\nUnique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'OfficeB', 'OfficeA', 'Lab1', 'Warehouse', 'Lab2'}

# %%
device_stats = {}

# Initialize the dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find the minimum and maximum values for each device type
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

# Display the results
print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(device, ":", stats)
# Out:
# Device Statistics:
# Temperature_Sensor : (18.38, 29.82)
# Humidity_Sensor : (33.55, 77.13)
# Pressure_Sensor : (980.31, 1029.92)
# Light_Sensor : (182.4, 998.0)

# %%
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
sample_string = "PythonProgrammingIsFun"
# Extract elements from the 10th to the 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

# Print the results
print("\nReadings from 10th to 20th (inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# Readings from 10th to 20th (inclusive):
# ('2026-07-19 15:01:37', 'DEV010', 'Humidity_Sensor', 'Lab2', 44.9)
# ('2026-07-19 15:01:37', 'DEV011', 'Light_Sensor', 'Lab1', 279.14)
# ('2026-07-19 15:01:37', 'DEV012', 'Temperature_Sensor', 'Lab2', 19.93)
# ('2026-07-19 15:01:37', 'DEV013', 'Light_Sensor', 'Lab2', 285.04)
# ('2026-07-19 15:01:37', 'DEV014', 'Light_Sensor', 'Warehouse', 694.46)
# ('2026-07-19 15:01:37', 'DEV015', 'Pressure_Sensor', 'OfficeB', 1022.87)
# ('2026-07-19 15:01:37', 'DEV016', 'Light_Sensor', 'Lab2', 864.94)
# ('2026-07-19 15:01:37', 'DEV017', 'Humidity_Sensor', 'OfficeB', 33.55)
# ('2026-07-19 15:01:37', 'DEV018', 'Pressure_Sensor', 'OfficeB', 1005.07)
# ('2026-07-19 15:01:37', 'DEV019', 'Light_Sensor', 'OfficeA', 289.42)
# ('2026-07-19 15:01:37', 'DEV020', 'Humidity_Sensor', 'Lab2', 67.15)
#
# Every 5th reading:
# ('2026-07-19 15:01:37', 'DEV001', 'Light_Sensor', 'Lab2', 998.0)
# ('2026-07-19 15:01:37', 'DEV006', 'Temperature_Sensor', 'Lab1', 22.97)
# ('2026-07-19 15:01:37', 'DEV011', 'Light_Sensor', 'Lab1', 279.14)
# ('2026-07-19 15:01:37', 'DEV016', 'Light_Sensor', 'Lab2', 864.94)
# ('2026-07-19 15:01:37', 'DEV021', 'Light_Sensor', 'Lab1', 880.17)
# ('2026-07-19 15:01:37', 'DEV026', 'Pressure_Sensor', 'Warehouse', 1018.84)
# ('2026-07-19 15:01:37', 'DEV031', 'Humidity_Sensor', 'Lab2', 46.22)
# ('2026-07-19 15:01:37', 'DEV036', 'Temperature_Sensor', 'Lab1', 25.56)
# ('2026-07-19 15:01:37', 'DEV041', 'Temperature_Sensor', 'OfficeB', 22.12)
# ('2026-07-19 15:01:37', 'DEV046', 'Humidity_Sensor', 'OfficeA', 77.13)
# ('2026-07-19 15:01:37', 'DEV051', 'Pressure_Sensor', 'OfficeA', 981.15)
# ('2026-07-19 15:01:37', 'DEV056', 'Humidity_Sensor', 'Warehouse', 61.68)
# ('2026-07-19 15:01:37', 'DEV061', 'Humidity_Sensor', 'OfficeB', 58.64)
# ('2026-07-19 15:01:37', 'DEV066', 'Light_Sensor', 'OfficeA', 669.51)
# ('2026-07-19 15:01:37', 'DEV071', 'Humidity_Sensor', 'OfficeB', 43.65)
# ('2026-07-19 15:01:37', 'DEV076', 'Humidity_Sensor', 'OfficeB', 75.79)
# ('2026-07-19 15:01:37', 'DEV081', 'Temperature_Sensor', 'Warehouse', 28.92)
# ('2026-07-19 15:01:37', 'DEV086', 'Light_Sensor', 'OfficeB', 182.4)
# ('2026-07-19 15:01:37', 'DEV091', 'Humidity_Sensor', 'Lab1', 55.2)
# ('2026-07-19 15:01:37', 'DEV096', 'Pressure_Sensor', 'Warehouse', 984.49)

# %%
# Extract the substring "Programming"
substring_1 = sample_string[6:17]

# Extract the reverse of "Python" -> "nohtyP"
substring_2 = sample_string[5::-1]

# Print the results
print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %%
# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

# Print the results
print("\n5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Light_Sensor
# Device Type Suffix: Sensor

# %%
# 2.1 Function to get readings by location
print("\n--- Task 2: Function Definitions and Usage ---")

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# Example usage
location = "Lab1"
lab1_readings = get_readings_by_location(raw_sensor_data, location)

print(f"\nSensor Readings for {location}:")
for reading in lab1_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
#
# Sensor Readings for Lab1:
# ('2026-07-19 15:01:37', 'DEV004', 'Temperature_Sensor', 'Lab1', 29.82)
# ('2026-07-19 15:01:37', 'DEV006', 'Temperature_Sensor', 'Lab1', 22.97)
# ('2026-07-19 15:01:37', 'DEV011', 'Light_Sensor', 'Lab1', 279.14)
# ('2026-07-19 15:01:37', 'DEV021', 'Light_Sensor', 'Lab1', 880.17)
# ('2026-07-19 15:01:37', 'DEV022', 'Humidity_Sensor', 'Lab1', 51.22)
# ('2026-07-19 15:01:37', 'DEV030', 'Pressure_Sensor', 'Lab1', 988.79)
# ('2026-07-19 15:01:37', 'DEV036', 'Temperature_Sensor', 'Lab1', 25.56)
# ('2026-07-19 15:01:37', 'DEV045', 'Pressure_Sensor', 'Lab1', 996.64)
# ('2026-07-19 15:01:37', 'DEV048', 'Temperature_Sensor', 'Lab1', 18.38)
# ('2026-07-19 15:01:37', 'DEV049', 'Humidity_Sensor', 'Lab1', 48.08)
# ('2026-07-19 15:01:37', 'DEV054', 'Temperature_Sensor', 'Lab1', 28.87)
# ('2026-07-19 15:01:37', 'DEV062', 'Light_Sensor', 'Lab1', 808.97)
# ('2026-07-19 15:01:37', 'DEV065', 'Pressure_Sensor', 'Lab1', 989.63)
# ('2026-07-19 15:01:37', 'DEV077', 'Light_Sensor', 'Lab1', 895.32)
# ('2026-07-19 15:01:37', 'DEV078', 'Humidity_Sensor', 'Lab1', 77.12)
# ('2026-07-19 15:01:37', 'DEV085', 'Temperature_Sensor', 'Lab1', 28.48)
# ('2026-07-19 15:01:37', 'DEV091', 'Humidity_Sensor', 'Lab1', 55.2)

# %%
# 2.2 Function to calculate average temperature

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return round(average, 2)


# Example usage
avg_temperature = calculate_average_temperature(temperature_readings)

print("\nAverage Temperature:", avg_temperature)
# Out:
# Average Temperature: 24.04

# %%
# 2.3 Function to generate a formatted report line

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"


# Example usage
if len(temperature_readings) > 0:
    report = generate_report_line(temperature_readings[0])
    print("\nReport Line:")
    print(report)
# Out:
# Report Line:
# [2026-07-19 15:01:37] Device DEV002 at OfficeA: 27.65°C

# %%
# 3.1 Use the os module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.
print("\n--- Task 3: Core Library Usage ---")


reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.

# %%
# 3.2 Calculate the duration between the first and last timestamp

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string timestamps to datetime objects
    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    # Calculate duration
    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
# 3.3 Generate a list of 5 random integers between 100 and 200 (inclusive)

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [142, 128, 109, 172, 143]
