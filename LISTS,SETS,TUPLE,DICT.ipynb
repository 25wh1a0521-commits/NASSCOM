# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0521-commits/NASSCOM/blob/main/LISTS%2CSETS%2CTUPLE%2CDICT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits=['apple','banana','custard apple','papaya','jackfruit']
print(fruits[0])
print(fruits)
# Out:
# apple
# ['apple', 'banana', 'custard apple', 'papaya', 'jackfruit']

# %%
fruits.append('guava')
print(fruits)
print(len(fruits))
fruits.remove('guava')
print(fruits)
# Out:
# ['apple', 'banana', 'custard apple', 'papaya', 'jackfruit', 'guava', 'guava', 'guava']
# 8
# ['apple', 'banana', 'custard apple', 'papaya', 'jackfruit', 'guava', 'guava']

# %%
points=(20,39,69)
print(points)
# Out:
# (20, 39, 69)

# %%
print(points[1])
# Out:
# 39

# %%
roll_no={23,23,45,45,67,89,90}
roll_no=set(roll_no)
print(roll_no)
# Out:
# {67, 23, 89, 90, 45}

# %%
roll_no.add(65)
print(roll_no)
# Out:
# {65, 67, 23, 89, 90, 45}

# %%
roll_no.remove(65)
print(roll_no)
# Out:
# {67, 23, 89, 90, 45}

# %%
seta={2,3,4}
setb={4,6,7}
print(seta|setb)
print(seta&setb)
# Out:
# {2, 3, 4, 6, 7}
# {4}

# %%
employe={'name':'Sharanya','salary':'400000','id':45678}
print(employe)
# Out:
# {'name': 'Sharanya', 'salary': '400000', 'id': 45678}

# %%
print(employe['salary'])
# Out:
# 400000

# %%
student = {
    'name': 'Alice',
    'age': 21,
    'course': 'Python'
}
print("Dictionary:", student)

# %%
print("Student name:", student['name'])

# %%
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}

# %% [markdown]
# # New section
